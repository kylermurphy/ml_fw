# %% [markdown]
# ### Space weather data ARIMA test # 1

# %%
import pandas as pd 

fn = r"C:\Data\fcc_database_v1.hdf5"

data = pd.read_hdf(fn)

# %%
data.tail()
# Out:
#                   DateTime  HMAEX  HMAEY   EMAX   SDEX   SDEY   SDEP  \
# 280507 2022-12-31 19:00:00  31.26  74.06  74.52  14.76  25.95  14.88
# 280508 2022-12-31 20:00:00  33.48  89.31  93.87  16.83  22.00  19.57
# 280509 2022-12-31 21:00:00  47.51  71.91  73.03  19.55  29.16  19.42
# 280510 2022-12-31 22:00:00  27.24  51.95  53.00  11.97  19.66  11.93
# 280511 2022-12-31 23:00:00  17.21  32.84  36.79   7.32  12.79  10.48
#
#              mlat       mlon        mlt  ...  sigAPratio   Esw  Beta  \
# 280507  67.365836 -24.280961  12.298359  ...         NaN -1.95  0.94
# 280508  67.365828 -24.280953  13.243339  ...         NaN  0.49  1.15
# 280509  67.365820 -24.280946  14.200666  ...         NaN  0.60  0.84
# 280510  67.365813 -24.280938  15.167596  ...         NaN -0.41  0.68
# 280511  67.365805 -24.280930  16.149475  ...         NaN -0.06  0.65
#
#         AlfvenMach    Kp  nSunSpot   Dst  AE  AL  AU
# 280507         8.7  33.0      91.0 -25.0 NaN NaN NaN
# 280508         9.3  33.0      91.0 -22.0 NaN NaN NaN
# 280509         8.5  40.0      91.0 -25.0 NaN NaN NaN
# 280510         7.9  40.0      91.0 -26.0 NaN NaN NaN
# 280511         7.8  40.0      91.0 -24.0 NaN NaN NaN
#
# [5 rows x 52 columns]

# %%
data.describe()
# Out:
#                             DateTime          HMAEX          HMAEY  \
# count                         280512  270016.000000  270839.000000
# mean   2006-12-31 23:30:00.000000256      40.315690      54.183961
# min              1991-01-01 00:00:00       0.320000       0.380000
# 25%              1998-12-31 23:45:00       8.150000      12.050000
# 50%              2006-12-31 23:30:00      17.830000      27.340000
# 75%              2014-12-31 23:15:00      44.220000      62.610000
# max              2022-12-31 23:00:00    2429.450000    3128.440000
# std                              NaN      64.712049      81.292551
#
#                 EMAX           SDEX           SDEY           SDEP  \
# count  269925.000000  270016.000000  270839.000000  269925.000000
# mean       62.140407      12.789249      17.376723      14.227346
# min         0.540000       0.130000       0.150000       0.170000
# 25%        13.660000       2.850000       4.240000       3.400000
# 50%        30.460000       6.130000       9.370000       7.190000
# 75%        70.840000      14.660000      21.020000      16.750000
# max      3129.110000     499.630000     678.410000     519.890000
# std        93.765116      18.791687      23.342570      19.819023
#
#                 mlat           mlon            mlt  ...     sigAPratio  \
# count  280512.000000  280512.000000  280512.000000  ...  228576.000000
# mean       68.424733     -26.531300      11.924116  ...       0.004976
# min        67.365805     -29.058951       0.156250  ...       0.000000
# 25%        67.925671     -27.898620       5.968539  ...       0.002000
# 50%        68.462056     -26.588398      11.865674  ...       0.003000
# 75%        68.938598     -24.973739      17.792829  ...       0.006000
# max        69.329821     -24.280930      23.919582  ...       0.421000
# std         0.580189       1.507520       6.918689  ...       0.006055
#
#                  Esw           Beta     AlfvenMach             Kp  \
# count  255009.000000  253751.000000  253775.000000  279384.000000
# mean        0.025879       2.673456      10.016686      19.026383
# min       -36.110000       0.000000       0.000000       0.000000
# 25%        -0.580000       1.020000       7.100000       7.000000
# 50%         0.030000       1.690000       9.200000      17.000000
# 75%         0.630000       2.870000      11.700000      27.000000
# max        47.110000     359.890000     121.100000      90.000000
# std         1.373311       4.618566       4.910433      13.925129
#
#             nSunSpot            Dst             AE             AL  \
# count  279768.000000  280291.000000  237360.000000  237360.000000
# mean       48.821481     -12.808777     192.570425    -119.599452
# min         0.000000    -422.000000       3.000000   -2452.000000
# 25%        11.000000     -20.000000      50.000000    -165.000000
# 50%        36.000000      -9.000000     110.000000     -57.000000
# 75%        78.000000       0.000000     266.000000     -22.000000
# max       300.000000      95.000000    3195.000000      22.000000
# std        46.213380      20.837392     206.569421     149.598030
#
#                   AU
# count  237360.000000
# mean       72.799848
# min      -260.000000
# 25%        23.000000
# 50%        47.000000
# 75%        99.000000
# max      1550.000000
# std        71.856965
#
# [8 rows x 52 columns]

# %%
data.shape
# Out:
# (280512, 52)

# %%
data.info
# Out:
# <bound method DataFrame.info of                   DateTime   HMAEX   HMAEY    EMAX   SDEX    SDEY   SDEP  \
# 0      1991-01-01 00:00:00   64.62  188.23  199.01  16.66   37.35  22.11
# 1      1991-01-01 01:00:00  214.82  355.69  357.68  49.02  111.36  48.58
# 2      1991-01-01 02:00:00  193.01  151.16  226.23  47.63   46.41  51.54
# 3      1991-01-01 03:00:00   41.47   29.52   43.72  14.96   13.79  15.94
# 4      1991-01-01 04:00:00   70.29   48.47   73.12  25.06   14.81  25.15
# ...                    ...     ...     ...     ...    ...     ...    ...
# 280507 2022-12-31 19:00:00   31.26   74.06   74.52  14.76   25.95  14.88
# 280508 2022-12-31 20:00:00   33.48   89.31   93.87  16.83   22.00  19.57
# 280509 2022-12-31 21:00:00   47.51   71.91   73.03  19.55   29.16  19.42
# 280510 2022-12-31 22:00:00   27.24   51.95   53.00  11.97   19.66  11.93
# 280511 2022-12-31 23:00:00   17.21   32.84   36.79   7.32   12.79  10.48
#
#              mlat       mlon        mlt  ...  sigAPratio   Esw  Beta  \
# 0       69.329821 -29.058951  16.918200  ...         NaN   NaN   NaN
# 1       69.329817 -29.058933  17.951357  ...         NaN   NaN   NaN
# 2       69.329812 -29.058915  19.036830  ...         NaN   NaN   NaN
# 3       69.329807 -29.058897  20.145792  ...         NaN   NaN   NaN
# 4       69.329803 -29.058880  21.249257  ...         NaN   NaN   NaN
# ...           ...        ...        ...  ...         ...   ...   ...
# 280507  67.365836 -24.280961  12.298359  ...         NaN -1.95  0.94
# 280508  67.365828 -24.280953  13.243339  ...         NaN  0.49  1.15
# 280509  67.365820 -24.280946  14.200666  ...         NaN  0.60  0.84
# 280510  67.365813 -24.280938  15.167596  ...         NaN -0.41  0.68
# 280511  67.365805 -24.280930  16.149475  ...         NaN -0.06  0.65
#
#         AlfvenMach    Kp  nSunSpot   Dst     AE     AL     AU
# 0              NaN  40.0     139.0 -27.0  332.0 -286.0   46.0
# 1              NaN  40.0     139.0 -29.0  471.0 -404.0   67.0
# 2              NaN  40.0     139.0 -28.0  349.0 -188.0  161.0
# 3              NaN  27.0     139.0 -29.0  208.0  -93.0  115.0
# 4              NaN  27.0     139.0 -32.0  216.0 -121.0   94.0
# ...            ...   ...       ...   ...    ...    ...    ...
# 280507         8.7  33.0      91.0 -25.0    NaN    NaN    NaN
# 280508         9.3  33.0      91.0 -22.0    NaN    NaN    NaN
# 280509         8.5  40.0      91.0 -25.0    NaN    NaN    NaN
# 280510         7.9  40.0      91.0 -26.0    NaN    NaN    NaN
# 280511         7.8  40.0      91.0 -24.0    NaN    NaN    NaN
#
# [280512 rows x 52 columns]>

# %%
data['DateTime'].min(), data['DateTime'].max()
# Out:
# (Timestamp('1991-01-01 00:00:00'), Timestamp('2022-12-31 23:00:00'))

# %%
type(data)
# Out:
# pandas.DataFrame

# %%
data.plot(x = 'DateTime', y = 'Dst', subplots = True, xlim = ('2015', '2020'), figsize =(6,10))
# Out:
# array([<Axes: xlabel='DateTime'>], dtype=object)

# %%
series = data.loc['2015-01-01':'2020-12-31' , 'Dst']

# %%
import numpy as np
import matplotlib.pyplot as plt

mean = np.mean(series)
print(mean)

variance = np.var(series)
print(variance)

print(series.index.min())
print(series.index.max())

plt.figure()
plt.plot(series.index,series) 
plt.xlabel("Date")
plt.ylabel("Dst")
plt.title("Dst vs Date")
plt.show()
# Out:
# -7.648
# 92.94809599999999
# 201500
# 201999

# %%
data['DateTime'] = pd.to_datetime(data['DateTime'])
data = data.sort_values('DateTime')
data = data.set_index('DateTime')

series = data.loc['2015-01-01':'2020-12-31', 'Dst']

print(series.index.min())
print(series.index.max())
print(len(series))

plt.figure()
plt.plot(series.index, series)
plt.xlabel("Date")
plt.ylabel("Dst")
plt.title("Dst vs Date")
plt.show()
# Out:
# 2015-01-01 00:00:00
# 2020-12-31 23:00:00
# 52608

# %% [markdown]
# Let's plot the ACF and do a Dicky fuller test, we'll use the carrington rotation of 27 days (648 hours)
#
# source https://nso.edu/data/nisp-data/synoptic-maps/#:~:text=Solar%20latitudes%20are

# %%
from statsmodels.tsa.stattools import adfuller

series_array = series.to_numpy()

acf_values = []


for lag in range(1, 649):
    products = [] 
    
    for i in range(len(series_array)):
         if i >= lag:
           mul = (series_array[i] - mean) * (series_array[i-lag] - mean) 
           
           products.append(float(mul))

    autocov = sum(products) / len(products)
    autocorr = autocov / variance

    acf_values.append(float(autocorr))
    
lags = list(range(1,649))

result = adfuller(series)

print("ADF Statistic:" , result[0])
print("p-value:", result[1])

critical_value = 1.96 / np.sqrt(52608) 

plt.figure()
plt.stem(lags,acf_values) 
plt.axhline(critical_value,linestyle='--')
plt.axhline(-critical_value,linestyle='--')
plt.xlabel("Lag")
plt.ylabel("ACF")
plt.title("ACF vs Lag")
plt.show()
# Out:
# ADF Statistic: -18.157809227776983
# p-value: 2.465970843675729e-30

# %% [markdown]
# ACF slowly decays indiciating non-stationarity. The Dicky fuller test argues, but clearly the data is not stationary. Let's difference the data

# %%
series_diff = np.diff(series_array)

diff_acf_values = []

diff_mean = np.mean(series_diff)
print(diff_mean)

diff_variance = np.var(series_diff)
print(diff_variance)

for lag in range(1, 649):
    products = [] 
    
    for i in range(len(series_diff)):
         if i >= lag:
           mul = (series_diff[i] - diff_mean) * (series_diff[i-lag] - diff_mean) 
           
           products.append(float(mul))

    diff_autocov = sum(products) / len(products)
    diff_autocorr = diff_autocov / diff_variance

    diff_acf_values.append(float(diff_autocorr))

critical_value = 1.96 / np.sqrt(len(series_diff)) 

plt.figure(figsize=(12,6))
plt.stem(lags,diff_acf_values) 
plt.axhline(critical_value,linestyle='--')
plt.axhline(-critical_value,linestyle='--')
plt.xlabel("Lag")
plt.ylabel("Differenced Data")
plt.title("Differenced Data vs Lag")
plt.show()
# Out:
# 0.00032315091147565913
# 13.605014437364506

# %% [markdown]
# Looks alot better, but not a clean decay. Likely due to noisy data? Clear spike at 1, so maybe we can choose a q = 1 . Let's check the PACF

# %%
from statsmodels.tsa.stattools import pacf

pacf_values = pacf(series_diff, 648)

plt.figure(figsize=(12,6))
plt.stem(lags,pacf_values[1:])
plt.axhline(critical_value,linestyle='--')
plt.axhline(-critical_value,linestyle='--')
plt.xlabel("Lag")
plt.ylabel("PACF")
plt.title("PACF vs Lag")
plt.show()

# %% [markdown]
# PACF is also not clean, but does show a significant spike at both lags 1 and 2. In any case, we will use the arimad function to automate it. But first out of curiosity, we will also confirm the seasonality situation by specifically finding the time values at which the dst level is below 50. "The minimum value during a storm will be between −50 and approximately −600 nT." from wikipedia. I want to check this, because it looks seasonal to me from the ACF graph.

# %%
dst_events = series[series < -50]

for t, v in dst_events.items():
    print(t, v)
# Out:
# 2015-01-04 13:00:00 -51.0
# 2015-01-04 14:00:00 -56.0
# 2015-01-04 15:00:00 -55.0
# 2015-01-04 16:00:00 -62.0
# 2015-01-04 17:00:00 -51.0
# 2015-01-04 18:00:00 -56.0
# 2015-01-04 19:00:00 -58.0
# 2015-01-04 20:00:00 -61.0
# 2015-01-04 21:00:00 -71.0
# 2015-01-04 22:00:00 -61.0
# 2015-01-04 23:00:00 -52.0
# 2015-01-05 00:00:00 -62.0
# 2015-01-07 09:00:00 -66.0
# 2015-01-07 10:00:00 -97.0
# 2015-01-07 11:00:00 -99.0
# 2015-01-07 12:00:00 -93.0
# 2015-01-07 13:00:00 -93.0
# 2015-01-07 14:00:00 -95.0
# 2015-01-07 15:00:00 -90.0
# 2015-01-07 16:00:00 -80.0
# 2015-01-07 17:00:00 -66.0
# 2015-01-07 18:00:00 -54.0
# 2015-01-08 01:00:00 -52.0
# 2015-02-17 22:00:00 -61.0
# 2015-02-17 23:00:00 -62.0
# 2015-02-18 00:00:00 -64.0
# 2015-02-18 01:00:00 -57.0
# 2015-02-18 03:00:00 -53.0
# 2015-02-18 05:00:00 -52.0
# 2015-02-18 06:00:00 -56.0
# 2015-02-18 07:00:00 -58.0
# 2015-02-18 08:00:00 -57.0
# 2015-02-18 09:00:00 -53.0
# 2018-08-27 09:00:00 -62.0
# 2018-08-27 10:00:00 -59.0
# 2018-08-27 11:00:00 -58.0
# 2018-08-27 12:00:00 -56.0
# 2018-08-27 13:00:00 -54.0
# 2018-08-27 14:00:00 -57.0
# 2018-08-27 15:00:00 -63.0
# 2018-08-27 16:00:00 -63.0
# 2018-08-27 17:00:00 -61.0
# 2018-08-27 18:00:00 -55.0
# 2018-08-27 19:00:00 -55.0
# 2018-08-27 20:00:00 -52.0
# 2018-09-11 09:00:00 -57.0
# 2018-09-11 10:00:00 -60.0
# 2018-09-11 11:00:00 -55.0
# 2018-09-11 15:00:00 -51.0
# 2018-10-07 20:00:00 -52.0
# 2018-10-07 21:00:00 -53.0
# 2018-11-05 05:00:00 -53.0
# 2018-11-05 06:00:00 -53.0
# 2018-11-05 12:00:00 -51.0
# 2019-05-11 21:00:00 -51.0
# 2019-05-14 06:00:00 -55.0
# 2019-05-14 07:00:00 -65.0
# 2019-05-14 08:00:00 -58.0
# 2019-05-14 09:00:00 -54.0
# 2019-08-05 16:00:00 -51.0
# 2019-08-05 19:00:00 -52.0
# 2019-08-05 20:00:00 -53.0
# 2019-09-01 06:00:00 -52.0
# 2019-09-01 20:00:00 -51.0
# 2020-02-18 16:00:00 -52.0
# 2020-02-18 17:00:00 -52.0
# 2020-02-18 18:00:00 -51.0
# 2020-04-20 12:00:00 -59.0
# 2020-04-20 13:00:00 -56.0
# 2020-07-25 00:00:00 -52.0
# 2020-07-25 01:00:00 -52.0
# 2020-08-30 23:00:00 -53.0
# 2020-08-31 00:00:00 -59.0
# 2020-08-31 01:00:00 -56.0
# 2020-08-31 02:00:00 -51.0
# 2020-08-31 04:00:00 -52.0
# 2020-08-31 05:00:00 -52.0
# 2020-09-28 00:00:00 -54.0
# 2020-09-28 03:00:00 -57.0
# 2020-09-28 04:00:00 -55.0
# 2020-09-28 07:00:00 -56.0
# 2020-09-28 08:00:00 -52.0

# %% [markdown]
# There is no clear 27 day pattern, although I do see it somewhat, there are storms in between the 27 day carrington rotation. So I will assume no clear seasonality, and I will move forward with the ARIMA test.

# %%
from pmdarima import auto_arima

model = auto_arima(
    series,
    seasonal=False,      
    trace=True,          
    stepwise=True
)

print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=278488.594, Time=44.82 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=286623.533, Time=0.86 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=281047.547, Time=1.15 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=279800.105, Time=3.39 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=286621.534, Time=0.42 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=41.26 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=279231.763, Time=8.79 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=278352.722, Time=59.77 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=58.98 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=65.77 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=278492.346, Time=46.61 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=278459.740, Time=61.13 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=59.49 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=70.02 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=inf, Time=24.95 sec
#
# Best model:  ARIMA(3,1,2)(0,0,0)[0] intercept
# Total fit time: 547.416 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                52608
# Model:               SARIMAX(3, 1, 2)   Log Likelihood             -139169.361
# Date:                Tue, 12 May 2026   AIC                         278352.722
# Time:                        04:09:26   BIC                         278414.816
# Sample:                    01-01-2015   HQIC                        278372.127
#                          - 12-31-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept  -1.187e-05      0.000     -0.050      0.960      -0.000       0.000
# ar.L1          1.3897      0.017     83.316      0.000       1.357       1.422
# ar.L2         -0.5969      0.021    -27.789      0.000      -0.639      -0.555
# ar.L3          0.1594      0.006     25.360      0.000       0.147       0.172
# ma.L1         -1.0401      0.017    -60.869      0.000      -1.074      -1.007
# ma.L2          0.0547      0.017      3.292      0.001       0.022       0.087
# sigma2        11.6105      0.027    426.139      0.000      11.557      11.664
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.26   Jarque-Bera (JB):            474063.51
# Prob(Q):                              0.61   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.46   Skew:                            -1.33
# Prob(H) (two-sided):                  0.00   Kurtosis:                        17.46
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# Looks like ARIMA (4,1,1) is the best fit. Let's graph it vs the actual data and check out how it's fitting.

# %%
fitted_values = model.predict_in_sample()

plt.figure()
plt.plot(series, label="Actual")
plt.plot(fitted_values, label="Fitted")
plt.legend()
plt.title("ARIMA Fit vs Actual")
plt.show()

# %% [markdown]
# Model looks good. Let's check the residuals and get the corresponding ACF. We expect it to look like white noise.

# %%
from statsmodels.graphics.tsaplots import plot_acf

residuals = model.resid()

plt.figure()
plt.plot(residuals)
plt.title("Residuals")
plt.show() 

plot_acf(residuals)
plt.title("Residual ACF")
plt.show()

# %%
print(len(residuals))
# Out:
# 52608

# %%
from sampling_methods import sample_block

block_results = sample_block(residuals, 52608)
print(len(block_results))
# Out:
# 52608

# %%
plt.figure()
plt.plot(residuals.index, block_results, label="Block sampled residuals")
plt.plot(residuals.index, residuals, label="Original residuals", alpha=0.5)
plt.legend()
plt.show()

# %%
from scipy.stats import ks_2samp

block_ks_stat, block_p_value = ks_2samp(residuals, block_results)

print("Block KS Statistic:", block_ks_stat)
print("Block P-value:", block_p_value)
# Out:
# Block KS Statistic: 0.003535583941605913
# Block P-value: 0.8962087501200791

# %%
from diagnostics import diagnostic_plot

# %%
diagnostic_plot(block_results)

# %%
diagnostic_plot(residuals)

# %% [markdown]
# Our model looks good. Let's forecast for 6 hours ahead, and well compare that to the original model to check, and see how accurate it is.

# %%
n_periods = 7

forecast = model.predict(n_periods=n_periods)

forecast_index = pd.date_range(
        start = series.index[-1] + pd.Timedelta(hours=1),
        periods = n_periods,
        freq = 'h'
)

future_series = data.loc[forecast_index, 'Dst'] 

ensemble_block = []

for i in range(20):

    block_results = sample_block(residuals, n_periods)

    forecast_perturbed = forecast + block_results

    ensemble_block.append(forecast_perturbed)

for i in range(20):
    plt.plot(forecast_index, ensemble_block[i], alpha=0.3, color='red')

plt.plot(future_series.index, future_series, label='Actual Dst')

plt.xlabel("Date")
plt.ylabel("Dst")
plt.title("Dst Forecast using Auto ARIMA")
plt.legend()
plt.show()

# %% [markdown]
# Looks okay. But seems to follow the direction somewhat. Let's compute the RMSE and MAE error for future comparison.

# %%
error = future_series.to_numpy() - forecast

mae = np.mean(np.abs(error))
rmse = np.sqrt(np.mean(error**2))

print("Errors:", error)
print("MAE:", mae)
print("RMSE:", rmse)
# Out:
# Errors: 2021-01-01 00:00:00   -3.921859
# 2021-01-01 01:00:00   -4.674084
# 2021-01-01 02:00:00   -4.376394
# 2021-01-01 03:00:00   -6.098140
# 2021-01-01 04:00:00   -5.849655
# 2021-01-01 05:00:00   -5.622985
# 2021-01-01 06:00:00   -7.411957
# Freq: h, dtype: float64
# MAE: 5.422153445829347
# RMSE: 5.533556181514986

# %% [markdown]
# Let's try the same with the solwar wind Esw

# %%
data.plot( x = 'DateTime' , y = 'Esw' , subplots = True, xlim = ('2015','2020'))
# Out:
# array([<Axes: xlabel='DateTime'>], dtype=object)

# %%
import numpy as np
import matplotlib.pyplot as plt
from pmdarima import auto_arima
from sampling_methods import sample_gaussian, sample_empirical, sample_kde, sample_block

data['DateTime'] = pd.to_datetime(data['DateTime'])
data = data.sort_values('DateTime')
data = data.set_index('DateTime')

series = data.loc['2015-01-01':'2020-12-31', 'Esw'].dropna()

model = auto_arima(
    series,
    seasonal=False,      
    trace=True,          
    stepwise=True
)

print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=127755.151, Time=6.56 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=158750.133, Time=0.28 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=128355.435, Time=0.66 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=137766.186, Time=1.23 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=127939.194, Time=2.83 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=127804.427, Time=9.09 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=127765.088, Time=17.38 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=127755.199, Time=7.33 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=128271.206, Time=1.43 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=127782.826, Time=3.96 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=127753.781, Time=9.26 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=128071.957, Time=1.11 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=127754.689, Time=12.75 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=128288.561, Time=0.87 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=127933.741, Time=1.38 sec
#  ARIMA(4,0,2)(0,0,0)[0]             : AIC=127757.615, Time=6.13 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=127732.183, Time=29.58 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=127784.578, Time=27.01 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=128038.608, Time=2.46 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : AIC=127732.763, Time=27.78 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=127758.090, Time=37.10 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=128250.361, Time=2.16 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=127733.760, Time=18.92 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=127903.851, Time=2.87 sec
#  ARIMA(4,0,2)(0,0,0)[0] intercept   : AIC=127735.964, Time=16.40 sec
#
# Best model:  ARIMA(3,0,1)(0,0,0)[0] intercept
# Total fit time: 246.559 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                52429
# Model:               SARIMAX(3, 0, 1)   Log Likelihood              -63860.091
# Date:                Fri, 01 May 2026   AIC                         127732.183
# Time:                        02:32:34   BIC                         127785.386
# Sample:                             0   HQIC                        127748.812
#                               - 52429
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0044      0.001      4.693      0.000       0.003       0.006
# ar.L1          1.3768      0.010    141.723      0.000       1.358       1.396
# ar.L2         -0.4799      0.006    -82.972      0.000      -0.491      -0.469
# ar.L3          0.0402      0.002     19.035      0.000       0.036       0.044
# ma.L1         -0.7481      0.010    -75.583      0.000      -0.768      -0.729
# sigma2         0.6691      0.001    507.950      0.000       0.667       0.672
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):           1234708.94
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.35   Skew:                             0.23
# Prob(H) (two-sided):                  0.00   Kurtosis:                        26.77
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
fitted_values = model.predict_in_sample()

plt.figure()
plt.plot(series, label="Actual")
plt.plot(fitted_values, label="Fitted")
plt.legend()
plt.title("ARIMA Fit vs Actual")
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf

residuals = model.resid()

plt.figure()
plt.plot(residuals)
plt.title("Residuals")
plt.show() 

plot_acf(residuals)
plt.title("Residual ACF")
plt.show()

# %%
n_periods = 7

forecast = model.predict(n_periods=n_periods)

forecast_index = pd.date_range(
        start = series.index[-1] + pd.Timedelta(hours=1),
        periods = n_periods,
        freq = 'h'
)

future_series = data.loc[forecast_index, 'Esw']


plt.figure(figsize=(14,5))

plt.plot(future_series.index, future_series, label='Actual Esw')
plt.plot(forecast_index, forecast, label='Forecast', color='red')

plt.xlabel("Date")
plt.ylabel("Esw")
plt.title("Esw Forecast using Auto ARIMA")
plt.legend()
plt.show()
# Out:
# c:\Users\Jeff\anaconda3\envs\research\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\Jeff\anaconda3\envs\research\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
error = future_series.to_numpy() - forecast

mae = np.mean(np.abs(error))
rmse = np.sqrt(np.mean(error**2))

print("Errors:", error)
print("MAE:", mae)
print("RMSE:", rmse)
# Out:
# Errors: 52429   -0.177401
# 52430   -0.322877
# 52431    0.251644
# 52432   -0.542183
# 52433   -0.458562
# 52434    0.162716
# 52435   -0.142166
# dtype: float64
# MAE: 0.2939355204159372
# RMSE: 0.3273212753716886

# %% [markdown]
# Let's try the same process for HMAEX, but using a shorter window of one year.

# %%
data.plot( x = 'DateTime' , y = 'HMAEX' , subplots = True, xlim = ('2015','2016'))
# Out:
# array([<Axes: xlabel='DateTime'>], dtype=object)

# %%
import numpy as np
import matplotlib.pyplot as plt
from pmdarima import auto_arima

data['DateTime'] = pd.to_datetime(data['DateTime'])
data = data.sort_values('DateTime')
data = data.set_index('DateTime')

series = data.loc['2015-01-01':'2015-01-31', 'HMAEX'].dropna()

model = auto_arima(
    series,
    seasonal=False,      
    trace=True,          
    stepwise=True
)

print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.41 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=8231.091, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=8185.481, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=8144.211, Time=0.10 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=8229.091, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=8045.589, Time=0.16 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.24 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=8015.196, Time=0.31 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=8016.782, Time=0.46 sec
#  ARIMA(0,1,4)(0,0,0)[0] intercept   : AIC=8016.830, Time=0.39 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=8018.646, Time=0.48 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=8013.302, Time=0.16 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=8043.613, Time=0.09 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=8014.912, Time=0.28 sec
#  ARIMA(0,1,4)(0,0,0)[0]             : AIC=8014.955, Time=0.25 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=8016.210, Time=0.17 sec
#  ARIMA(1,1,4)(0,0,0)[0]             : AIC=8016.760, Time=0.41 sec
#
# Best model:  ARIMA(0,1,3)(0,0,0)[0]
# Total fit time: 4.162 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  744
# Model:               SARIMAX(0, 1, 3)   Log Likelihood               -4002.651
# Date:                Fri, 01 May 2026   AIC                           8013.302
# Time:                        02:55:51   BIC                           8031.745
# Sample:                    01-01-2015   HQIC                          8020.412
#                          - 01-31-2015
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.5122      0.013    -40.387      0.000      -0.537      -0.487
# ma.L2         -0.2485      0.031     -7.984      0.000      -0.310      -0.188
# ma.L3         -0.2094      0.021     -9.780      0.000      -0.251      -0.167
# sigma2      2787.6318     25.369    109.882      0.000    2737.909    2837.355
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):            399521.00
# Prob(Q):                              0.91   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.12   Skew:                             6.47
# Prob(H) (two-sided):                  0.00   Kurtosis:                       115.86
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
fitted_values = model.predict_in_sample()

plt.figure()
plt.plot(series, label="Actual")
plt.plot(fitted_values, label="Fitted")
plt.legend()
plt.title("ARIMA Fit vs Actual")
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf

residuals = model.resid()

plt.figure()
plt.plot(residuals)
plt.title("Residuals")
plt.show() 

plot_acf(residuals)b
plt.title("Residual ACF")
plt.show()

# %%
n_periods = 7

forecast = model.predict(n_periods=n_periods)

forecast_index = pd.date_range(
        start = series.index[-1] + pd.Timedelta(hours=1),
        periods = n_periods,
        freq = 'h'
)

future_series = data.loc[forecast_index, 'HMAEX']


plt.figure(figsize=(14,5))

plt.plot(future_series.index, future_series, label='Actual HMAEX')
plt.plot(forecast_index, forecast, label='Forecast', color='red')

plt.xlabel("Date")
plt.ylabel("HMAEX")
plt.title("HMAEX Forecast using Auto ARIMA")
plt.legend()
plt.show()

# %%
error = future_series.to_numpy() - forecast

mae = np.mean(np.abs(error))
rmse = np.sqrt(np.mean(error**2))

print("Errors:", error)
print("MAE:", mae)
print("RMSE:", rmse)b
# Out:
# Errors: 2015-02-01 00:00:00    -10.163449
# 2015-02-01 01:00:00     -7.180256
# 2015-02-01 02:00:00    234.164697
# 2015-02-01 03:00:00     -1.675303
# 2015-02-01 04:00:00     -5.945303
# 2015-02-01 05:00:00    -17.225303
# 2015-02-01 06:00:00    -13.075303
# Freq: h, dtype: float64
# MAE: 41.347087869594866
# RMSE: 89.03754011962894

# %% [markdown]
# Quite inaccurate, could be because of the shorter window ( I think this is likely) but I cannot say for sure that this is the sole reason. Let's try for AE, this time we will use a longer window of 18 years.

# %%
data.plot( x = 'DateTime' , y = 'AE' , subplots = True, xlim = ('2000','2018'))
# Out:
# array([<Axes: xlabel='DateTime'>], dtype=object)

# %%
import numpy as np
import matplotlib.pyplot as plt
from pmdarima import auto_arima

data['DateTime'] = pd.to_datetime(data['DateTime'])
data = data.sort_values('DateTime')
data = data.set_index('DateTime')

series = data.loc['2000-01-01':'2018-01-31', 'AE'].dropna()

model = auto_arima(
    series,
    seasonal=False,      
    trace=True,          
    stepwise=True
)

print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=1925507.829, Time=49.74 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1946551.122, Time=1.72 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1946416.890, Time=2.11 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1946256.876, Time=14.12 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1946549.122, Time=0.87 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=1925880.053, Time=41.30 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=1927101.598, Time=36.84 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=92.48 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=1923842.175, Time=123.55 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=72.98 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=1924002.073, Time=133.64 sec
#  ARIMA(2,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=133.61 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=96.15 sec
#  ARIMA(3,1,4)(0,0,0)[0] intercept   : AIC=1925861.145, Time=105.16 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=1923831.672, Time=56.57 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=inf, Time=36.39 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=1925505.825, Time=19.04 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=1923911.829, Time=60.91 sec
#  ARIMA(2,1,4)(0,0,0)[0]             : AIC=inf, Time=62.87 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=1925878.050, Time=16.40 sec
#  ARIMA(1,1,4)(0,0,0)[0]             : AIC=inf, Time=37.09 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=inf, Time=47.25 sec
#  ARIMA(3,1,4)(0,0,0)[0]             : AIC=1925859.144, Time=48.47 sec
#
# Best model:  ARIMA(2,1,3)(0,0,0)[0]
# Total fit time: 1289.262 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:               157800
# Model:               SARIMAX(2, 1, 3)   Log Likelihood             -961909.836
# Date:                Fri, 01 May 2026   AIC                        1923831.672
# Time:                        03:27:02   BIC                        1923891.487
# Sample:                             0   HQIC                       1923849.460
#                              - 157800
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.1769      0.007    176.755      0.000       1.164       1.190
# ar.L2         -0.2381      0.005    -45.148      0.000      -0.248      -0.228
# ma.L1         -1.2926      0.007   -197.971      0.000      -1.305      -1.280
# ma.L2          0.0130      0.006      2.010      0.044       0.000       0.026
# ma.L3          0.2842      0.002    150.333      0.000       0.280       0.288
# sigma2      1.161e+04     17.776    653.231      0.000    1.16e+04    1.16e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                  39.27   Jarque-Bera (JB):            605285.92
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.69   Skew:                             1.28
# Prob(H) (two-sided):                  0.00   Kurtosis:                        12.25
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
fitted_values = model.predict_in_sample()

plt.figure()
plt.plot(series, label="Actual")
plt.plot(fitted_values, label="Fitted")
plt.legend()
plt.title("ARIMA Fit vs Actual")
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf

residuals = model.resid()

plt.figure()
plt.plot(residuals)
plt.title("Residuals")
plt.show() 

plot_acf(residuals)
plt.title("Residual ACF")
plt.show()

# %%
n_periods = 3

forecast = model.predict(n_periods=n_periods)

forecast_index = pd.date_range(
        start = series.index[-1] + pd.Timedelta(hours=1),
        periods = n_periods,
        freq = 'h'
)

future_series = data.loc[forecast_index, 'AE']


plt.figure(figsize=(14,5))

plt.plot(future_series.index, future_series, label='Actual AE')
plt.plot(forecast_index, forecast, label='Forecast', color='red')

plt.xlabel("Date")
plt.ylabel("AE")
plt.title("AE Forecast using Auto ARIMA")
plt.legend()
plt.show()
# Out:
# c:\Users\Jeff\anaconda3\envs\research\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\Jeff\anaconda3\envs\research\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
error = future_series.to_numpy() - forecast

mae = np.mean(np.abs(error))
rmse = np.sqrt(np.mean(error**2))

print("Errors:", error)
print("MAE:", mae)
print("RMSE:", rmse)
# Out:
# Errors: 157800    -54.251485
# 157801    -41.718844
# 157802   -106.160347
# dtype: float64
# MAE: 67.37689167755336
# RMSE: 72.92394372897418

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 


fn = r"C:\Data\fcc_database_v1.hdf5"

data = pd.read_hdf(fn)

data.shape

data.describe
# Out:
# <bound method NDFrame.describe of                   DateTime   HMAEX   HMAEY    EMAX   SDEX    SDEY   SDEP  \
# 0      1991-01-01 00:00:00   64.62  188.23  199.01  16.66   37.35  22.11
# 1      1991-01-01 01:00:00  214.82  355.69  357.68  49.02  111.36  48.58
# 2      1991-01-01 02:00:00  193.01  151.16  226.23  47.63   46.41  51.54
# 3      1991-01-01 03:00:00   41.47   29.52   43.72  14.96   13.79  15.94
# 4      1991-01-01 04:00:00   70.29   48.47   73.12  25.06   14.81  25.15
# ...                    ...     ...     ...     ...    ...     ...    ...
# 280507 2022-12-31 19:00:00   31.26   74.06   74.52  14.76   25.95  14.88
# 280508 2022-12-31 20:00:00   33.48   89.31   93.87  16.83   22.00  19.57
# 280509 2022-12-31 21:00:00   47.51   71.91   73.03  19.55   29.16  19.42
# 280510 2022-12-31 22:00:00   27.24   51.95   53.00  11.97   19.66  11.93
# 280511 2022-12-31 23:00:00   17.21   32.84   36.79   7.32   12.79  10.48
#
#              mlat       mlon        mlt  ...  sigAPratio   Esw  Beta  \
# 0       69.329821 -29.058951  16.918200  ...         NaN   NaN   NaN
# 1       69.329817 -29.058933  17.951357  ...         NaN   NaN   NaN
# 2       69.329812 -29.058915  19.036830  ...         NaN   NaN   NaN
# 3       69.329807 -29.058897  20.145792  ...         NaN   NaN   NaN
# 4       69.329803 -29.058880  21.249257  ...         NaN   NaN   NaN
# ...           ...        ...        ...  ...         ...   ...   ...
# 280507  67.365836 -24.280961  12.298359  ...         NaN -1.95  0.94
# 280508  67.365828 -24.280953  13.243339  ...         NaN  0.49  1.15
# 280509  67.365820 -24.280946  14.200666  ...         NaN  0.60  0.84
# 280510  67.365813 -24.280938  15.167596  ...         NaN -0.41  0.68
# 280511  67.365805 -24.280930  16.149475  ...         NaN -0.06  0.65
#
#         AlfvenMach    Kp  nSunSpot   Dst     AE     AL     AU
# 0              NaN  40.0     139.0 -27.0  332.0 -286.0   46.0
# 1              NaN  40.0     139.0 -29.0  471.0 -404.0   67.0
# 2              NaN  40.0     139.0 -28.0  349.0 -188.0  161.0
# 3              NaN  27.0     139.0 -29.0  208.0  -93.0  115.0
# 4              NaN  27.0     139.0 -32.0  216.0 -121.0   94.0
# ...            ...   ...       ...   ...    ...    ...    ...
# 280507         8.7  33.0      91.0 -25.0    NaN    NaN    NaN
# 280508         9.3  33.0      91.0 -22.0    NaN    NaN    NaN
# 280509         8.5  40.0      91.0 -25.0    NaN    NaN    NaN
# 280510         7.9  40.0      91.0 -26.0    NaN    NaN    NaN
# 280511         7.8  40.0      91.0 -24.0    NaN    NaN    NaN
#
# [280512 rows x 52 columns]>

# %%
data.plot(x = 'DateTime', y = 'HMAEY' , xlim = ('1995-01-01', '1995-12-31'))
# Out:
# <Axes: xlabel='DateTime'>

# %%
from pmdarima import auto_arima  

data['DateTime'] = pd.to_datetime(data['DateTime'])
data = data.set_index('DateTime')

series = data.loc['1995-01-01' : '1995-12-31' , 'HMAEY'].dropna()

print(series)

model = auto_arima(
    series,
    seasonal = False,
    Trace = True, 
    stepwise = True 
)

print(model.summary())
# Out:
# DateTime
# 1995-01-01 00:00:00     9.11
# 1995-01-01 01:00:00    11.05
# 1995-01-01 02:00:00    12.67
# 1995-01-01 03:00:00     9.17
# 1995-01-01 04:00:00    25.34
#                        ...
# 1995-12-31 19:00:00    25.43
# 1995-12-31 20:00:00    16.47
# 1995-12-31 21:00:00    28.69
# 1995-12-31 22:00:00    41.52
# 1995-12-31 23:00:00    37.19
# Name: HMAEY, Length: 8760, dtype: float64
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 8760
# Model:               SARIMAX(1, 1, 4)   Log Likelihood              -50692.447
# Date:                Fri, 01 May 2026   AIC                         101396.893
# Time:                        22:19:18   BIC                         101439.360
# Sample:                    01-01-1995   HQIC                        101411.364
#                          - 12-31-1995
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5068      0.052      9.721      0.000       0.405       0.609
# ma.L1         -1.0776      0.053    -20.518      0.000      -1.181      -0.975
# ma.L2          0.0768      0.031      2.455      0.014       0.015       0.138
# ma.L3          0.0892      0.014      6.414      0.000       0.062       0.116
# ma.L4         -0.0495      0.010     -5.110      0.000      -0.069      -0.031
# sigma2      6228.4543     21.050    295.891      0.000    6187.197    6269.711
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):            616974.28
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.88   Skew:                             4.59
# Prob(H) (two-sided):                  0.00   Kurtosis:                        43.08
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
fitted_values = model.predict_in_sample()


plt.figure(figsize = (14,5))
plt.plot(series , label = "Actual")
plt.plot(fitted_values, label = "Fitted")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from statsmodels.graphics.tsaplots import plot_acf

residuals = model.resid()


plt.figure()
plot_acf(residuals)
plt.show

plt.figure() 
plt.plot(residuals)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
forecast = model.predict(n_periods = 3)

forecast_index = pd.date_range(
    start = series.index[-1] + pd.Timedelta(hours =1),
    freq = 'h',
    periods = 3
)

future_series = data.loc[forecast_index, 'HMAEY']

plt.figure(figsize = (14,5))
plt.plot(future_series.index, future_series, label = 'Actual')
plt.plot(forecast_index, forecast, label = 'Forecast', color = 'red')
plt.xlabel('Time')
plt.ylabel('HMAEY')
plt.legend() 
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
error = future_series.to_numpy() - forecast

RMSE = np.sqrt(np.mean(error**2))

MAE = np.mean(np.abs(error))

print(MAE)
print(RMSE)
# Out:
# 23.852191930933216
# 23.86719942970929

# %% [markdown]
# #### Let's do another one with Dst, we will import my diagnostics function to see how the residuals are.

# %%
import numpy as np 
import pandas as pd 
from diagnostics import diagnostic_plot
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
import matplotlib.pyplot as plt
from pmdarima import auto_arima  
from sampling_methods import sample_gaussian, sample_empirical, sample_kde, sample_block

# %%
fn = r"C:\Data\fcc_database_v1.hdf5"

data = pd.read_hdf(fn)

data.shape

data.info
# Out:
# <bound method DataFrame.info of                   DateTime   HMAEX   HMAEY    EMAX   SDEX    SDEY   SDEP  \
# 0      1991-01-01 00:00:00   64.62  188.23  199.01  16.66   37.35  22.11
# 1      1991-01-01 01:00:00  214.82  355.69  357.68  49.02  111.36  48.58
# 2      1991-01-01 02:00:00  193.01  151.16  226.23  47.63   46.41  51.54
# 3      1991-01-01 03:00:00   41.47   29.52   43.72  14.96   13.79  15.94
# 4      1991-01-01 04:00:00   70.29   48.47   73.12  25.06   14.81  25.15
# ...                    ...     ...     ...     ...    ...     ...    ...
# 280507 2022-12-31 19:00:00   31.26   74.06   74.52  14.76   25.95  14.88
# 280508 2022-12-31 20:00:00   33.48   89.31   93.87  16.83   22.00  19.57
# 280509 2022-12-31 21:00:00   47.51   71.91   73.03  19.55   29.16  19.42
# 280510 2022-12-31 22:00:00   27.24   51.95   53.00  11.97   19.66  11.93
# 280511 2022-12-31 23:00:00   17.21   32.84   36.79   7.32   12.79  10.48
#
#              mlat       mlon        mlt  ...  sigAPratio   Esw  Beta  \
# 0       69.329821 -29.058951  16.918200  ...         NaN   NaN   NaN
# 1       69.329817 -29.058933  17.951357  ...         NaN   NaN   NaN
# 2       69.329812 -29.058915  19.036830  ...         NaN   NaN   NaN
# 3       69.329807 -29.058897  20.145792  ...         NaN   NaN   NaN
# 4       69.329803 -29.058880  21.249257  ...         NaN   NaN   NaN
# ...           ...        ...        ...  ...         ...   ...   ...
# 280507  67.365836 -24.280961  12.298359  ...         NaN -1.95  0.94
# 280508  67.365828 -24.280953  13.243339  ...         NaN  0.49  1.15
# 280509  67.365820 -24.280946  14.200666  ...         NaN  0.60  0.84
# 280510  67.365813 -24.280938  15.167596  ...         NaN -0.41  0.68
# 280511  67.365805 -24.280930  16.149475  ...         NaN -0.06  0.65
#
#         AlfvenMach    Kp  nSunSpot   Dst     AE     AL     AU
# 0              NaN  40.0     139.0 -27.0  332.0 -286.0   46.0
# 1              NaN  40.0     139.0 -29.0  471.0 -404.0   67.0
# 2              NaN  40.0     139.0 -28.0  349.0 -188.0  161.0
# 3              NaN  27.0     139.0 -29.0  208.0  -93.0  115.0
# 4              NaN  27.0     139.0 -32.0  216.0 -121.0   94.0
# ...            ...   ...       ...   ...    ...    ...    ...
# 280507         8.7  33.0      91.0 -25.0    NaN    NaN    NaN
# 280508         9.3  33.0      91.0 -22.0    NaN    NaN    NaN
# 280509         8.5  40.0      91.0 -25.0    NaN    NaN    NaN
# 280510         7.9  40.0      91.0 -26.0    NaN    NaN    NaN
# 280511         7.8  40.0      91.0 -24.0    NaN    NaN    NaN
#
# [280512 rows x 52 columns]>

# %%
series = data.loc['2000-01-01' : '2005-01-01', 'Dst']

# %%
plt.figure()
plt.plot(series.index, series)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data['DateTime']= pd.to_datetime(data['DateTime'])
data = data.set_index('DateTime')

# %%
series = data.loc['2000-01-01': '2005-01-01', 'Dst']

plt.figure(figsize = (16,4))
plt.plot(series.index,series)
plt.xlabel("Date")
plt.ylabel("Dst")
plt.title("Dst vs Date")
# Out:
# Text(0.5, 1.0, 'Dst vs Date')

# %%
plot_acf(series,lags = 365)
plot_pacf(series, lags = 365)

# %%
model = auto_arima(
    series,
    seasonality = False,
    trace = True, 
    stepwise = True 
)

print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=271543.973, Time=7.98 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=277159.732, Time=0.77 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=272135.222, Time=1.66 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=271596.221, Time=3.22 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=277157.733, Time=0.38 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=271552.310, Time=15.36 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=271549.283, Time=6.40 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=271544.558, Time=39.84 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=44.95 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=271574.226, Time=4.15 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=271545.771, Time=10.27 sec

# %%
residuals = model.resid()

# %%
diagnostic_plot(residuals)

# %% [markdown]
# Interesting, the QQ plot shows that the residual distribution deviates from the idea around -2 and 2 standard deviations below and above the mean. I'm going try ARIMAX to improve the model.

# %%
from pmdarima.model_selection import train_test_split

exog_cols = ['Kp', 'AE' , 'Esw']

target_col = ['Dst']

df = data.loc['2000-01-01':'2005-01-01', target_col + exog_cols].dropna()

y = df['Dst']
x = df[exog_cols].dropna()

split_date = '2004-01-01'

y_train = y.loc[:split_date]
y_test  = y.loc[split_date:]

X_train = x.loc[:split_date]
X_test  = x.loc[split_date:]

print(len(x))
print(len(y))
# Out:
# 43775
# 43775

# %%
model = auto_arima(
    y_train,
    X=X_train,
    seasonal=False,
    trace=True,
    stepwise=True
)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=217376.573, Time=33.55 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=221395.091, Time=4.69 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=218068.815, Time=6.98 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=217853.896, Time=5.03 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=221393.092, Time=8.29 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=217805.484, Time=15.43 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=217769.358, Time=7.30 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=217772.395, Time=32.51 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=217754.619, Time=37.56 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=217812.891, Time=7.72 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=217759.969, Time=28.73 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=217770.257, Time=12.17 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=217759.553, Time=38.06 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=217265.915, Time=30.03 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=217803.485, Time=13.65 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=217767.358, Time=6.41 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=217770.490, Time=22.22 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=217749.267, Time=31.92 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=217810.891, Time=6.69 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=217757.972, Time=23.51 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=217768.257, Time=10.67 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=217758.914, Time=37.75 sec
#
# Best model:  ARIMA(2,1,2)(0,0,0)[0]
# Total fit time: 420.904 seconds

# %%
residuals = model.resid()

diagnostic_plot(residuals)

# %% [markdown]
# Now let's do another example. 2003, where we have quite a few geomagnetic storms wit a Dst below -50. We will go through the whole process.

# %%
import numpy as np 
import pandas as pd 
from diagnostics import diagnostic_plot
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
import matplotlib.pyplot as plt
from pmdarima import auto_arima  
from sampling_methods import sample_gaussian, sample_empirical, sample_kde, sample_block

# %%
fn = r"C:\Data\fcc_database_v1.hdf5"

data = pd.read_hdf(fn)

# %%
data['DateTime']= pd.to_datetime(data['DateTime'])
data = data.set_index('DateTime')

# %%
series = data.loc['2003-01-01': '2003-12-31', 'Dst']

plt.figure(figsize = (16,4))
plt.plot(series.index,series)
plt.xlabel("Date")
plt.ylabel("Dst")
plt.title("Dst vs Date")
# Out:
# Text(0.5, 1.0, 'Dst vs Date')

# %%
plot_acf(series,lags = 365)
plot_pacf(series, lags = 365)

# %%
from arima_utils import diagnostic_plot, fit_arima_and_characterize, characterize_residuals

# %%
model, residuals, characterization, panel = fit_arima_and_characterize(series, title = "Dst", plot = True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=55123.307, Time=7.77 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=56453.192, Time=0.16 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=55308.520, Time=0.35 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=55153.336, Time=0.58 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=56451.192, Time=0.10 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=55131.861, Time=2.79 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=55135.571, Time=2.49 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=55117.851, Time=8.80 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=55133.757, Time=3.11 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=55116.581, Time=9.65 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=55124.839, Time=2.96 sec
#  ARIMA(5,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=10.90 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=54994.256, Time=12.00 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=55117.764, Time=9.66 sec
#  ARIMA(5,1,3)(0,0,0)[0] intercept   : AIC=54949.752, Time=11.87 sec
#  ARIMA(5,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=12.94 sec
#  ARIMA(4,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=11.91 sec
#  ARIMA(5,1,3)(0,0,0)[0]             : AIC=inf, Time=6.25 sec
#
# Best model:  ARIMA(5,1,3)(0,0,0)[0] intercept
# Total fit time: 114.301 seconds
# c:\Users\Jeff\anaconda3\envs\research\Lib\site-packages\scipy\stats\_axis_nan_policy.py:592: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 8760.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
print(characterization)
# Out:
# {'mean': 0.0017239364067948707, 'std': 5.565716745954367, 'skew': -2.4739154109340786, 'kurtosis': 40.55865834922553, 'shapiro_pvalue': 5.484427407348436e-71, 'ljung_box_pass': False, 'optimal_block_length': 20, 'recommended_method': 'Block Bootstrap is recommended'}

# %%
from sampling_methods import sample_block

# %%
print(len(residuals))
# Out:
# 8760

# %%
block_results = sample_block(residuals, block_length=20, n_samples= 8760)

# %%
plt.plot(block_results)

# %%
model = auto_arima(
    series,
    seasonality = False,
    trace = True, 
    stepwise = True 
)

print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=55123.307, Time=8.46 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=56453.192, Time=0.17 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=55308.520, Time=0.36 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=55153.336, Time=0.68 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=56451.192, Time=0.12 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=55131.861, Time=3.04 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=55135.571, Time=2.55 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=55117.851, Time=9.10 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=55133.757, Time=3.18 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=55116.581, Time=10.08 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=55124.839, Time=3.06 sec
#  ARIMA(5,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=11.55 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=54994.256, Time=12.38 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=55117.764, Time=9.89 sec
#  ARIMA(5,1,3)(0,0,0)[0] intercept   : AIC=54949.752, Time=12.00 sec
#  ARIMA(5,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=13.27 sec
#  ARIMA(4,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=12.04 sec
#  ARIMA(5,1,3)(0,0,0)[0]             : AIC=inf, Time=6.03 sec
#
# Best model:  ARIMA(5,1,3)(0,0,0)[0] intercept
# Total fit time: 117.953 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 8760
# Model:               SARIMAX(5, 1, 3)   Log Likelihood              -27464.876
# Date:                Tue, 12 May 2026   AIC                          54949.752
# Time:                        05:19:05   BIC                          55020.531
# Sample:                    01-01-2003   HQIC                         54973.869
#                          - 12-31-2003
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept  -4.279e-05      0.001     -0.030      0.976      -0.003       0.003
# ar.L1          0.9707      0.073     13.219      0.000       0.827       1.115
# ar.L2          0.1572      0.124      1.265      0.206      -0.086       0.401
# ar.L3         -0.2557      0.096     -2.653      0.008      -0.445      -0.067
# ar.L4          0.1594      0.036      4.466      0.000       0.089       0.229
# ar.L5         -0.0904      0.009    -10.141      0.000      -0.108      -0.073
# ma.L1         -0.5837      0.074     -7.921      0.000      -0.728      -0.439
# ma.L2         -0.5392      0.101     -5.334      0.000      -0.737      -0.341
# ma.L3          0.1430      0.060      2.382      0.017       0.025       0.261
# sigma2        30.8681      0.116    266.609      0.000      30.641      31.095
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.16   Jarque-Bera (JB):            609422.59
# Prob(Q):                              0.69   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.25   Skew:                            -2.47
# Prob(H) (two-sided):                  0.00   Kurtosis:                        43.56
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
fitted_values = model.predict_in_sample()

plt.figure()
plt.plot(series, label="Actual")
plt.plot(fitted_values, label="Fitted", alpha= 0.4)
plt.legend()
plt.title("ARIMA Fit vs Actual")
plt.show()

# %%
residuals = model.resid()

# %%
plt.figure()
plot_acf(residuals)
plt.show

plt.figure() 
plt.plot(residuals)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
diagnostic_plot(residuals)

# %%
print(len(series))
# Out:
# 8760

# %%
block_results = sample_block(residuals,8760)

# %%
diagnostic_plot(block_results)

# %%
from scipy.stats import ks_2samp

block_ks_stat, block_p_value = ks_2samp(residuals, block_results)

print("Block KS Statistic:", block_ks_stat)
print("Block P-value:", block_p_value)
# Out:
# Block KS Statistic: 0.010958904109589041
# Block P-value: 0.6688775422430775

# %%
n_periods = 3

forecast = model.predict(n_periods=n_periods)

forecast_index = pd.date_range(
        start = series.index[-1] + pd.Timedelta(hours=1),
        periods = n_periods,
        freq = 'h'
)

future_series = data.loc[forecast_index, 'Dst'] 

ensemble_block = []

for i in range(20):

    block_results = sample_block(residuals, n_periods)

    forecast_perturbed = forecast + block_results

    ensemble_block.append(forecast_perturbed)

for i in range(20):
    plt.plot(forecast_index, ensemble_block[i], alpha=0.3, color='red')

plt.plot(future_series.index, future_series, label='Actual Dst')
plt.xticks(rotation=45)
plt.xlabel("Date")
plt.ylabel("Dst")
plt.title("Dst Forecast using Auto ARIMA")
plt.legend()
plt.show()

# %%
ensemble_array = np.array(ensemble_block)

forecast_mean = np.mean(ensemble_array, axis = 0)

# %%
plt.figure()
plt.plot(forecast_index, forecast_mean)
plt.xticks(rotation=45)

plt.xlabel("Date")
plt.ylabel("Dst")
plt.title("Forecast Mean")
# Out:
# Text(0.5, 1.0, 'Forecast Mean')

# %%
dst_events = series[series < -50]

for t, v in dst_events.items():
    print(t, v)
# Out:
# 2003-01-29 23:00:00 -63.0
# 2003-01-30 00:00:00 -66.0
# 2003-01-30 01:00:00 -57.0
# 2003-02-02 07:00:00 -54.0
# 2003-02-02 09:00:00 -59.0
# 2003-02-02 10:00:00 -67.0
# 2003-02-02 11:00:00 -61.0
# 2003-02-02 12:00:00 -65.0
# 2003-02-02 13:00:00 -61.0
# 2003-02-02 14:00:00 -66.0
# 2003-02-02 15:00:00 -72.0
# 2003-02-02 16:00:00 -65.0
# 2003-02-02 17:00:00 -72.0
# 2003-02-02 18:00:00 -71.0
# 2003-02-02 19:00:00 -57.0
# 2003-02-02 20:00:00 -68.0
# 2003-02-02 21:00:00 -72.0
# 2003-02-02 22:00:00 -71.0
# 2003-02-02 23:00:00 -68.0
# 2003-02-03 00:00:00 -59.0
# 2003-02-03 01:00:00 -58.0
# 2003-02-03 02:00:00 -58.0
# 2003-02-03 03:00:00 -55.0
# 2003-02-03 04:00:00 -53.0
# 2003-02-03 10:00:00 -54.0
# 2003-11-22 20:00:00 -86.0
# 2003-11-22 21:00:00 -83.0
# 2003-11-22 22:00:00 -87.0
# 2003-11-22 23:00:00 -86.0
# 2003-11-23 00:00:00 -79.0
# 2003-11-23 01:00:00 -69.0
# 2003-11-23 02:00:00 -65.0
# 2003-11-23 03:00:00 -73.0
# 2003-11-23 04:00:00 -74.0
# 2003-11-23 05:00:00 -74.0
# 2003-11-23 06:00:00 -66.0
# 2003-11-23 07:00:00 -70.0
# 2003-11-23 08:00:00 -71.0
# 2003-11-23 09:00:00 -66.0
# 2003-11-23 10:00:00 -59.0
# 2003-11-23 11:00:00 -51.0
# 2003-12-06 03:00:00 -52.0
# 2003-12-06 04:00:00 -55.0
# 2003-12-08 21:00:00 -54.0
# 2003-12-09 00:00:00 -53.0
# 2003-12-10 19:00:00 -51.0

# %%
series.index.get_loc('2003-11-20 11:00:00')
# Out:
# 7763

# %%
n_periods = 7

forecast = model.predict(n_periods=n_periods)

forecast_index = pd.date_range(
        start = series.index[7763] + pd.Timedelta(hours=1),
        periods = n_periods,
        freq = 'h'
)

future_series = data.loc[forecast_index, 'Dst'] 

ensemble_block = []

for i in range(20):

    block_results = sample_block(residuals, n_periods)

    forecast_perturbed = forecast + block_results

    ensemble_block.append(forecast_perturbed)

for i in range(20):
    plt.plot(forecast_index, ensemble_block[i], alpha=0.3, color='red')

plt.plot(future_series.index, future_series, label='Actual Dst')
plt.xticks(rotation=45)
plt.xlabel("Date")
plt.ylabel("Dst")
plt.title("Dst Forecast using Auto ARIMA")
plt.legend()
plt.show()

# %%
model = auto_arima(
    series.iloc[:7763],
    seasonality = False,
    trace = True, 
    stepwise = True 
)

print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=48534.650, Time=3.75 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=49556.785, Time=0.13 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=48756.316, Time=0.33 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=48589.299, Time=0.47 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=49554.800, Time=0.10 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=5.25 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=48532.894, Time=0.46 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=48591.178, Time=0.68 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=48534.526, Time=0.40 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=48533.198, Time=3.59 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=48532.765, Time=0.49 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=48534.424, Time=0.78 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=48535.198, Time=4.69 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=48530.777, Time=0.24 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=48532.538, Time=0.18 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : AIC=48532.436, Time=0.32 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=48531.210, Time=2.12 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=48530.906, Time=0.24 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : AIC=48533.210, Time=1.59 sec
#
# Best model:  ARIMA(3,1,0)(0,0,0)[0]
# Total fit time: 25.817 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 7763
# Model:               SARIMAX(3, 1, 0)   Log Likelihood              -24261.388
# Date:                Tue, 12 May 2026   AIC                          48530.777
# Time:                        06:11:45   BIC                          48558.605
# Sample:                    01-01-2003   HQIC                         48540.316
#                          - 11-20-2003
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3629      0.004     95.519      0.000       0.355       0.370
# ar.L2         -0.1608      0.005    -32.569      0.000      -0.171      -0.151
# ar.L3         -0.0221      0.005     -4.823      0.000      -0.031      -0.013
# sigma2        30.3726      0.114    266.497      0.000      30.149      30.596
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):            458327.56
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.31   Skew:                            -1.96
# Prob(H) (two-sided):                  0.00   Kurtosis:                        40.44
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
fitted_values = model.predict_in_sample()

plt.figure()
plt.plot(series, label="Actual")
plt.plot(fitted_values, label="Fitted", alpha= 0.4)
plt.legend()
plt.title("ARIMA Fit vs Actual")
plt.show()

# %%
n_periods = 3

forecast = model.predict(n_periods=n_periods)

forecast_index = pd.date_range(
        start = series.index[7763] + pd.Timedelta(hours=1),
        periods = n_periods,
        freq = 'h'
)

future_series = data.loc[forecast_index, 'Dst'] 

ensemble_block = []

for i in range(20):

    block_results = sample_block(residuals, n_periods)

    forecast_perturbed = forecast + block_results

    ensemble_block.append(forecast_perturbed)

for i in range(20):
    plt.plot(forecast_index, ensemble_block[i], alpha=0.3, color='red')

plt.plot(future_series.index, future_series, label='Actual Dst')
plt.xticks(rotation=45)
plt.xlabel("Date")
plt.ylabel("Dst")
plt.title("Dst Forecast using Auto ARIMA")
plt.legend()
plt.show()

# %% [markdown]
# Let's do another test run

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
data= pd.read_hdf(r"C:\Data\fcc_database_v1.hdf5")

# %%
print(len(data))
# Out:
# 280512

# %%
data.info
# Out:
# <bound method DataFrame.info of                   DateTime   HMAEX   HMAEY    EMAX   SDEX    SDEY   SDEP  \
# 0      1991-01-01 00:00:00   64.62  188.23  199.01  16.66   37.35  22.11
# 1      1991-01-01 01:00:00  214.82  355.69  357.68  49.02  111.36  48.58
# 2      1991-01-01 02:00:00  193.01  151.16  226.23  47.63   46.41  51.54
# 3      1991-01-01 03:00:00   41.47   29.52   43.72  14.96   13.79  15.94
# 4      1991-01-01 04:00:00   70.29   48.47   73.12  25.06   14.81  25.15
# ...                    ...     ...     ...     ...    ...     ...    ...
# 280507 2022-12-31 19:00:00   31.26   74.06   74.52  14.76   25.95  14.88
# 280508 2022-12-31 20:00:00   33.48   89.31   93.87  16.83   22.00  19.57
# 280509 2022-12-31 21:00:00   47.51   71.91   73.03  19.55   29.16  19.42
# 280510 2022-12-31 22:00:00   27.24   51.95   53.00  11.97   19.66  11.93
# 280511 2022-12-31 23:00:00   17.21   32.84   36.79   7.32   12.79  10.48
#
#              mlat       mlon        mlt  ...  sigAPratio   Esw  Beta  \
# 0       69.329821 -29.058951  16.918200  ...         NaN   NaN   NaN
# 1       69.329817 -29.058933  17.951357  ...         NaN   NaN   NaN
# 2       69.329812 -29.058915  19.036830  ...         NaN   NaN   NaN
# 3       69.329807 -29.058897  20.145792  ...         NaN   NaN   NaN
# 4       69.329803 -29.058880  21.249257  ...         NaN   NaN   NaN
# ...           ...        ...        ...  ...         ...   ...   ...
# 280507  67.365836 -24.280961  12.298359  ...         NaN -1.95  0.94
# 280508  67.365828 -24.280953  13.243339  ...         NaN  0.49  1.15
# 280509  67.365820 -24.280946  14.200666  ...         NaN  0.60  0.84
# 280510  67.365813 -24.280938  15.167596  ...         NaN -0.41  0.68
# 280511  67.365805 -24.280930  16.149475  ...         NaN -0.06  0.65
#
#         AlfvenMach    Kp  nSunSpot   Dst     AE     AL     AU
# 0              NaN  40.0     139.0 -27.0  332.0 -286.0   46.0
# 1              NaN  40.0     139.0 -29.0  471.0 -404.0   67.0
# 2              NaN  40.0     139.0 -28.0  349.0 -188.0  161.0
# 3              NaN  27.0     139.0 -29.0  208.0  -93.0  115.0
# 4              NaN  27.0     139.0 -32.0  216.0 -121.0   94.0
# ...            ...   ...       ...   ...    ...    ...    ...
# 280507         8.7  33.0      91.0 -25.0    NaN    NaN    NaN
# 280508         9.3  33.0      91.0 -22.0    NaN    NaN    NaN
# 280509         8.5  40.0      91.0 -25.0    NaN    NaN    NaN
# 280510         7.9  40.0      91.0 -26.0    NaN    NaN    NaN
# 280511         7.8  40.0      91.0 -24.0    NaN    NaN    NaN
#
# [280512 rows x 52 columns]>

# %%
data["DateTime"] = pd.to_datetime(data['DateTime'])
data = data.set_index(['DateTime'])

# %%
series = data.loc["2022-01-01":"2022-12-31", "Dst"]

# %%
plt.plot(series.index, series)

# %%
from arima_utils import fit_arima_and_characterize, characterize_residuals, diagnostic_plot

# %%
model, residuals, characterization, panel = fit_arima_and_characterize(series, title = "Dst", plot = True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=48599.722, Time=5.32 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=49899.348, Time=0.15 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=49031.823, Time=0.55 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=48859.640, Time=0.77 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=49897.354, Time=0.12 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=48612.141, Time=4.22 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=48800.799, Time=1.58 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=48804.764, Time=3.15 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=48594.470, Time=8.61 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=48596.456, Time=4.98 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=48603.722, Time=7.49 sec
#  ARIMA(2,1,4)(0,0,0)[0] intercept   : AIC=48600.305, Time=4.94 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=48590.096, Time=5.29 sec
#  ARIMA(0,1,4)(0,0,0)[0] intercept   : AIC=48792.450, Time=1.39 sec
#  ARIMA(1,1,5)(0,0,0)[0] intercept   : AIC=48590.227, Time=7.66 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=48814.874, Time=1.28 sec
#  ARIMA(0,1,5)(0,0,0)[0] intercept   : AIC=48794.446, Time=2.01 sec
#  ARIMA(2,1,5)(0,0,0)[0] intercept   : AIC=inf, Time=11.77 sec
#  ARIMA(1,1,4)(0,0,0)[0]             : AIC=48588.161, Time=2.10 sec
#  ARIMA(0,1,4)(0,0,0)[0]             : AIC=48790.455, Time=0.68 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=48594.513, Time=1.72 sec
#  ARIMA(2,1,4)(0,0,0)[0]             : AIC=48589.697, Time=5.63 sec
#  ARIMA(1,1,5)(0,0,0)[0]             : AIC=48588.296, Time=2.11 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=48812.879, Time=0.53 sec
#  ARIMA(0,1,5)(0,0,0)[0]             : AIC=48792.451, Time=0.94 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=48592.528, Time=2.77 sec
#  ARIMA(2,1,5)(0,0,0)[0]             : AIC=inf, Time=5.75 sec
#
# Best model:  ARIMA(1,1,4)(0,0,0)[0]
# Total fit time: 93.514 seconds
# c:\Users\Jeff\anaconda3\envs\research\Lib\site-packages\scipy\stats\_axis_nan_policy.py:592: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 8760.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
from sampling_methods import sample_block

# %%
sample_block(series.index, series, residuals, plot = True, ensemble = True)
# Out:
# (array([ 3.7091194 ,  2.28060408,  0.86402789, ...,  1.67408392,
#         -9.28496769,  4.57615688], shape=(8760,)),
#  [DateTime
#   2022-01-01 00:00:00     7.427840
#   2022-01-01 01:00:00    -6.220002
#   2022-01-01 02:00:00   -14.847644
#   2022-01-01 03:00:00    -9.374980
#   2022-01-01 04:00:00   -18.525372
#                            ...
#   2022-12-31 19:00:00   -23.293719
#   2022-12-31 20:00:00   -20.193857
#   2022-12-31 21:00:00   -23.103395
#   2022-12-31 22:00:00   -23.008679
#   2022-12-31 23:00:00   -25.241745
#   Name: Dst, Length: 8760, dtype: float64,
#   DateTime
#   2022-01-01 00:00:00     6.617991
#   2022-01-01 01:00:00    -3.075697
#   2022-01-01 02:00:00    -4.666722
#   2022-01-01 03:00:00   -12.551704
#   2022-01-01 04:00:00   -21.514544
#                            ...
#   2022-12-31 19:00:00   -28.136698
#   2022-12-31 20:00:00   -35.077836
#   2022-12-31 21:00:00   -32.791846
#   2022-12-31 22:00:00   -23.592831
#   2022-12-31 23:00:00   -18.050649
#   Name: Dst, Length: 8760, dtype: float64,
#   DateTime
#   2022-01-01 00:00:00
#   Name: Dst, Length: 8760, dtype: float64,
#   DateTime
#   2022-01-01 00:00:00     0.441718
#   2022-01-01 01:00:00    -1.821849
#   2022-01-01 02:00:00     3.506193
#   2022-01-01 03:00:00   -22.747933
#   2022-01-01 04:00:00   -18.895854
#                            ...
#   2022-12-31 19:00:00   -25.200170
#   2022-12-31 20:00:00   -22.882548
#   2022-12-31 21:00:00   -25.536212
#   2022-12-31 22:00:00   -33.987802
#   2022-12-31 23:00:00   -24.707886
#   Name: Dst, Length: 8760, dtype: float64,
#   DateTime
#   2022-01-01 00:00:00     8.581376
#   2022-01-01 01:00:00     0.780465
#   2022-01-01 02:00:00    -3.964020
#   2022-01-01 03:00:00   -11.377528
#   2022-01-01 04:00:00   -20.213951
#                            ...
#   2022-12-31 19:00:00   -21.524334
#   2022-12-31 20:00:00   -19.628198
#   2022-12-31 21:00:00   -22.572657
#   2022-12-31 22:00:00   -28.260644
#   2022-12-31 23:00:00   -21.507017
#   Name: Dst, Length: 8760, dtype: float64,
#   DateTime
#   2022-01-01 00:00:00     9.709119
#   2022-01-01 01:00:00    -0.719396
#   2022-01-01 02:00:00    -6.135972
#   2022-01-01 03:00:00   -11.323127
#   2022-01-01 04:00:00   -19.263395
#                            ...
#   2022-12-31 19:00:00   -23.931741
#   2022-12-31 20:00:00   -18.348072
#   2022-12-31 21:00:00   -23.325916
#   2022-12-31 22:00:00   -35.284968
#   2022-12-31 23:00:00   -19.423843
#   Name: Dst, Length: 8760, dtype: float64],
#  <Figure size 640x480 with 1 Axes>)

# %%
data = pd.read_hdf(r"C:\Data\fcc_database_v1.hdf5")

# %%
data.info
# Out:
# <bound method DataFrame.info of                   DateTime   HMAEX   HMAEY    EMAX   SDEX    SDEY   SDEP  \
# 0      1991-01-01 00:00:00   64.62  188.23  199.01  16.66   37.35  22.11
# 1      1991-01-01 01:00:00  214.82  355.69  357.68  49.02  111.36  48.58
# 2      1991-01-01 02:00:00  193.01  151.16  226.23  47.63   46.41  51.54
# 3      1991-01-01 03:00:00   41.47   29.52   43.72  14.96   13.79  15.94
# 4      1991-01-01 04:00:00   70.29   48.47   73.12  25.06   14.81  25.15
# ...                    ...     ...     ...     ...    ...     ...    ...
# 280507 2022-12-31 19:00:00   31.26   74.06   74.52  14.76   25.95  14.88
# 280508 2022-12-31 20:00:00   33.48   89.31   93.87  16.83   22.00  19.57
# 280509 2022-12-31 21:00:00   47.51   71.91   73.03  19.55   29.16  19.42
# 280510 2022-12-31 22:00:00   27.24   51.95   53.00  11.97   19.66  11.93
# 280511 2022-12-31 23:00:00   17.21   32.84   36.79   7.32   12.79  10.48
#
#              mlat       mlon        mlt  ...  sigAPratio   Esw  Beta  \
# 0       69.329821 -29.058951  16.918200  ...         NaN   NaN   NaN
# 1       69.329817 -29.058933  17.951357  ...         NaN   NaN   NaN
# 2       69.329812 -29.058915  19.036830  ...         NaN   NaN   NaN
# 3       69.329807 -29.058897  20.145792  ...         NaN   NaN   NaN
# 4       69.329803 -29.058880  21.249257  ...         NaN   NaN   NaN
# ...           ...        ...        ...  ...         ...   ...   ...
# 280507  67.365836 -24.280961  12.298359  ...         NaN -1.95  0.94
# 280508  67.365828 -24.280953  13.243339  ...         NaN  0.49  1.15
# 280509  67.365820 -24.280946  14.200666  ...         NaN  0.60  0.84
# 280510  67.365813 -24.280938  15.167596  ...         NaN -0.41  0.68
# 280511  67.365805 -24.280930  16.149475  ...         NaN -0.06  0.65
#
#         AlfvenMach    Kp  nSunSpot   Dst     AE     AL     AU
# 0              NaN  40.0     139.0 -27.0  332.0 -286.0   46.0
# 1              NaN  40.0     139.0 -29.0  471.0 -404.0   67.0
# 2              NaN  40.0     139.0 -28.0  349.0 -188.0  161.0
# 3              NaN  27.0     139.0 -29.0  208.0  -93.0  115.0
# 4              NaN  27.0     139.0 -32.0  216.0 -121.0   94.0
# ...            ...   ...       ...   ...    ...    ...    ...
# 280507         8.7  33.0      91.0 -25.0    NaN    NaN    NaN
# 280508         9.3  33.0      91.0 -22.0    NaN    NaN    NaN
# 280509         8.5  40.0      91.0 -25.0    NaN    NaN    NaN
# 280510         7.9  40.0      91.0 -26.0    NaN    NaN    NaN
# 280511         7.8  40.0      91.0 -24.0    NaN    NaN    NaN
#
# [280512 rows x 52 columns]>

# %%
data['DateTime'] = pd.to_datetime(data['DateTime'])

# %%
data = data.set_index('DateTime')

# %%
series = data.loc["2010-01-01": "2010-06-01" , "Esw"].dropna()

# %%
import matplotlib.pyplot as plt 

plt.plot(series.index,series
         )

# %%
from arima_utils import fit_arima_and_characterize, diagnostic_plot, characterize_residuals

# %%
model, residuals, characterization, panel = fit_arima_and_characterize(series, title = "Esw", plot = True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=7408.873, Time=0.85 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=10381.367, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=7431.472, Time=0.12 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=8526.515, Time=0.15 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=7433.020, Time=0.28 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=7428.788, Time=0.89 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=7434.756, Time=1.54 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=7409.510, Time=0.95 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=7433.395, Time=0.14 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=7415.051, Time=0.44 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=7408.790, Time=1.21 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=7433.720, Time=0.27 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=7409.910, Time=0.98 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=7433.400, Time=0.20 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=7420.286, Time=0.25 sec
#  ARIMA(4,0,2)(0,0,0)[0]             : AIC=7402.988, Time=1.95 sec
#  ARIMA(5,0,2)(0,0,0)[0]             : AIC=7404.202, Time=2.09 sec
#  ARIMA(4,0,3)(0,0,0)[0]             : AIC=7404.434, Time=2.07 sec
#  ARIMA(3,0,3)(0,0,0)[0]             : AIC=7402.660, Time=1.42 sec
#  ARIMA(3,0,4)(0,0,0)[0]             : AIC=7404.327, Time=2.18 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=7407.405, Time=1.94 sec
#  ARIMA(4,0,4)(0,0,0)[0]             : AIC=7406.438, Time=2.32 sec
#  ARIMA(3,0,3)(0,0,0)[0] intercept   : AIC=7404.805, Time=3.53 sec
#
# Best model:  ARIMA(3,0,3)(0,0,0)[0]
# Total fit time: 25.808 seconds

# %%
print(characterization)
# Out:
# {'Sample count': 3644.0, 'mean': 0.002680844605748106, 'std': 0.6668276120045471, 'skew': 0.15413088528429736, 'kurtosis': 7.706153265916521, 'shapiro_pvalue': 3.114090356340591e-38, 'ljung_box_pass': False, 'optimal_block_length': 15, 'recommended_method': 'Block Bootstrap is recommended'}

# %%
from sampling_methods import sample_block

# %%
block_results, ensemble_block, fig = sample_block(series.index, series, residuals, plot = True, ensemble = True)
